# %%
print("hello world!")
# Out:
# hello world!

# %%
name = "saurabh singh"
college = "QUAD AI"
age = 19
print("my name is ", name)
print("my college name is ",college)
print("and my age is ", age)
# Out:
# my name is  saurabh singh
# my college name is  QUAD AI
# and my age is  19

# %%
# addition
a = 10
b = 25
c = 37
print("a+b+c=",a+b+c)
# Out:
# a+b+c= 72

# %%
print("i am learning python")
# Out:
# i am learning python

# %%
# DATA TYPES
name = "saurabh"
age = 19
height = 5.9
is_student = True

print(name)
print(type(name))

print(age)
print(type(age))

print(height)
print(type(height))

print(is_student)
print(type(is_student))
# Out:
# saurabh
# <class 'str'>
# 19
# <class 'int'>
# 5.9
# <class 'float'>
# True
# <class 'bool'>

# %%
# USER INPUT
name = input("enter your name")
print("hello",name)
# Out:
# enter your name saurabh
# hello saurabh

# %%
age = int(input("Enter your age"))
print(age)
print(type(age))
# Out:
# Enter your age 19
# 19
# <class 'int'>

# %%
name = input("enter your name")
print("welcome",name)
# Out:
# enter your name saurabh
# welcome saurabh

# %%
age = int(input("Enter your age"))
print("your age is:",age)
# Out:
# Enter your age 19
# your age is: 19

# %%
num1 = int(input("enter first num:"))
num2 = int(input("enter second num:"))

print("sum =",num1 + num2)
# Out:
# enter first num: 45
# enter second num: 35
# sum = 80

# %%
# OPERATORS
num1 = 25
nom2 = 30
print("add =",a+b)
print("sub =",a-b)
print("mul =",a*b)
print("div =",a/b)
print("mod =",a%b)
print("power =",a**b)
print("floor div =",a//b)
# Out:
# add = 55
# sub = -5
# mul = 750
# div = 0.8333333333333334
# mod = 25
# power = 867361737988403547205962240695953369140625
# floor div = 0
